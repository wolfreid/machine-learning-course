# %%
import pandas as pd

df = pd.read_csv('developer_dataset.csv')

print(df.columns)
# Out:
# Index(['RespondentID', 'Year', 'Country', 'Employment', 'UndergradMajor',
#        'DevType', 'LanguageWorkedWith', 'LanguageDesireNextYear',
#        'DatabaseWorkedWith', 'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'Hobbyist', 'OrgSize', 'YearsCodePro',
#        'JobSeek', 'ConvertedComp', 'WorkWeekHrs', 'NEWJobHunt',
#        'NEWJobHuntResearch', 'NEWLearn'],
#       dtype='object')
# C:\Users\roman.prylypko\AppData\Local\Temp\ipykernel_27092\2873554251.py:3: DtypeWarning: Columns (18,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('developer_dataset.csv')

# %%
df.head(10)
# Out:
#    RespondentID  Year        Country          Employment  \
# 0             1  2018  United States  Employed full-time
# 1             1  2019  United States  Employed full-time
# 2             1  2020  United States  Employed full-time
# 3             2  2018  United States  Employed full-time
# 4             2  2019  United States  Employed full-time
# 5             2  2020  United States  Employed full-time
# 6             3  2018  United States  Employed full-time
# 7             3  2019  United States  Employed full-time
# 8             3  2020  United States  Employed full-time
# 9             4  2018  United States  Employed full-time
#
#                                       UndergradMajor  \
# 0  Computer science, computer engineering, or sof...
# 1  Computer science, computer engineering, or sof...
# 2  Computer science, computer engineering, or sof...
# 3  Computer science, computer engineering, or sof...
# 4  Computer science, computer engineering, or sof...
# 5  Computer science, computer engineering, or sof...
# 6  Computer science, computer engineering, or sof...
# 7                                                NaN
# 8  Computer science, computer engineering, or sof...
# 9  Fine arts or performing arts (ex. graphic desi...
#
#                                              DevType  \
# 0           Engineering manager;Full-stack developer
# 1                              Developer, full-stack
# 2                                                NaN
# 3                               Full-stack developer
# 4  Data or business analyst;Database administrato...
# 5  Developer, back-end;Developer, desktop or ente...
# 6  Back-end developer;Front-end developer;Full-st...
# 7  Data or business analyst;Designer;Developer, b...
# 8  Developer, desktop or enterprise applications;...
# 9  Back-end developer;C-suite executive (CEO, CTO...
#
#                                   LanguageWorkedWith  \
# 0                                                NaN
# 1                                C;C++;C#;Python;SQL
# 2                                  HTML/CSS;Ruby;SQL
# 3   C#;JavaScript;SQL;TypeScript;HTML;CSS;Bash/Shell
# 4  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 5                                         Python;SQL
# 6                                JavaScript;HTML;CSS
# 7  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# 8                 HTML/CSS;JavaScript;SQL;TypeScript
# 9  Assembly;CoffeeScript;Erlang;Go;JavaScript;Lua...
#
#                               LanguageDesireNextYear  \
# 0                                                NaN
# 1                                C;C#;JavaScript;SQL
# 2                                    Java;Ruby;Scala
# 3   C#;JavaScript;SQL;TypeScript;HTML;CSS;Bash/Shell
# 4  Bash/Shell/PowerShell;HTML/CSS;JavaScript;Rust...
# 5                                         JavaScript
# 6                    C;Go;JavaScript;Python;HTML;CSS
# 7  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# 8                 HTML/CSS;JavaScript;SQL;TypeScript
# 9                          Erlang;Go;Python;Rust;SQL
#
#                                   DatabaseWorkedWith  \
# 0                                                NaN
# 1                                       MySQL;SQLite
# 2                      MySQL;PostgreSQL;Redis;SQLite
# 3  SQL Server;Microsoft Azure (Tables, CosmosDB, ...
# 4                  Couchbase;DynamoDB;Firebase;MySQL
# 5                                MariaDB;MySQL;Redis
# 6                                            MongoDB
# 7                   Elasticsearch;MySQL;Oracle;Redis
# 8                      Firebase;Microsoft SQL Server
# 9  Redis;PostgreSQL;Amazon DynamoDB;Apache HBase;...
#
#                               DatabaseDesireNextYear  ...  \
# 0                                                NaN  ...
# 1                                       MySQL;SQLite  ...
# 2                                   MySQL;PostgreSQL  ...
# 3  SQL Server;Microsoft Azure (Tables, CosmosDB, ...  ...
# 4                               Firebase;MySQL;Redis  ...
# 5                                            MongoDB  ...
# 6                                                NaN  ...
# 7                   Elasticsearch;MySQL;Oracle;Redis  ...
# 8                      Firebase;Microsoft SQL Server  ...
# 9  Redis;PostgreSQL;Amazon DynamoDB;Apache Hive;A...  ...
#
#                               PlatformDesireNextYear Hobbyist  \
# 0                                                NaN      NaN
# 1                                      Linux;Windows       No
# 2  Docker;Google Cloud Platform;Heroku;Linux;Windows      Yes
# 3                                              Azure      NaN
# 4  Android;AWS;Docker;IBM Cloud or Watson;Linux;S...      Yes
# 5                    iOS;Slack Apps and Integrations      Yes
# 6                                              Linux      NaN
# 7                  Docker;Linux;Raspberry Pi;Windows      Yes
# 8         Google Cloud Platform;Raspberry Pi;Windows      Yes
# 9                        AWS;Linux;Mac OS;Serverless      NaN
#
#                     OrgSize YearsCodePro  \
# 0                       NaN          NaN
# 1      100 to 499 employees          1.0
# 2                       NaN          8.0
# 3                       NaN          4.0
# 4        10 to 19 employees          8.0
# 5        20 to 99 employees         13.0
# 6                       NaN          1.0
# 7  10,000 or more employees         18.0
# 8      100 to 499 employees          1.0
# 9                       NaN         16.0
#
#                                              JobSeek ConvertedComp  \
# 0                                                NaN      141000.0
# 1       I am not interested in new job opportunities       61000.0
# 2                                                NaN           NaN
# 3                                                NaN       48000.0
# 4       I am not interested in new job opportunities       90000.0
# 5  I’m not actively looking, but I am open to new...      116000.0
# 6                                                NaN           NaN
# 7  I’m not actively looking, but I am open to new...      103000.0
# 8  I’m not actively looking, but I am open to new...       66000.0
# 9                                                NaN       58000.0
#
#    WorkWeekHrs                                         NEWJobHunt  \
# 0          NaN                                                NaN
# 1         80.0                                                NaN
# 2          NaN                                                NaN
# 3          NaN                                                NaN
# 4         40.0                                                NaN
# 5         39.0  Curious about other opportunities;Better compe...
# 6          NaN                                                NaN
# 7         40.0                                                NaN
# 8         40.0  Wanting to share accomplishments with a wider ...
# 9          NaN                                                NaN
#
#                                   NEWJobHuntResearch          NEWLearn
# 0                                                NaN               NaN
# 1                                                NaN               NaN
# 2                                                NaN       Once a year
# 3                                                NaN               NaN
# 4                                                NaN               NaN
# 5  Read company media, such as employee blogs or ...       Once a year
# 6                                                NaN               NaN
# 7                                                NaN               NaN
# 8  Read company media, such as employee blogs or ...  Every few months
# 9                                                NaN               NaN
#
# [10 rows x 21 columns]

# %%
df.count(), df.shape
# Out:
# (RespondentID              111209
#  Year                      111209
#  Country                   111209
#  Employment                109425
#  UndergradMajor             98453
#  DevType                   100433
#  LanguageWorkedWith        102018
#  LanguageDesireNextYear     96044
#  DatabaseWorkedWith         85859
#  DatabaseDesireNextYear     74234
#  PlatformWorkedWith         91609
#  PlatformDesireNextYear     85376
#  Hobbyist                   68352
#  OrgSize                    54804
#  YearsCodePro               94793
#  JobSeek                    60556
#  ConvertedComp              91333
#  WorkWeekHrs                51089
#  NEWJobHunt                 19127
#  NEWJobHuntResearch         18683
#  NEWLearn                   24226
#  dtype: int64,
#  (111209, 21))

# %%
df.describe()
# Out:
#         RespondentID           Year  YearsCodePro  ConvertedComp   WorkWeekHrs
# count  111209.000000  111209.000000  94793.000000   9.133300e+04  51089.000000
# mean    19262.039709    2018.854832      9.547045   1.251777e+05     41.051670
# std     11767.011322       0.777503      7.548931   2.461218e+05     13.833929
# min         1.000000    2018.000000      0.000000   0.000000e+00      1.000000
# 25%      9268.000000    2018.000000      4.000000   4.600000e+04     40.000000
# 50%     18535.000000    2019.000000      8.000000   7.900000e+04     40.000000
# 75%     28347.000000    2019.000000     14.000000   1.200000e+05     42.000000
# max     42857.000000    2020.000000     50.000000   2.000000e+06    475.000000

# %%
maxRows = df['RespondentID'].count()

# %%
df.head()
# Out:
#    RespondentID  Year        Country          Employment  \
# 0             1  2018  United States  Employed full-time
# 1             1  2019  United States  Employed full-time
# 2             1  2020  United States  Employed full-time
# 3             2  2018  United States  Employed full-time
# 4             2  2019  United States  Employed full-time
#
#                                       UndergradMajor  \
# 0  Computer science, computer engineering, or sof...
# 1  Computer science, computer engineering, or sof...
# 2  Computer science, computer engineering, or sof...
# 3  Computer science, computer engineering, or sof...
# 4  Computer science, computer engineering, or sof...
#
#                                              DevType  \
# 0           Engineering manager;Full-stack developer
# 1                              Developer, full-stack
# 2                                                NaN
# 3                               Full-stack developer
# 4  Data or business analyst;Database administrato...
#
#                                   LanguageWorkedWith  \
# 0                                                NaN
# 1                                C;C++;C#;Python;SQL
# 2                                  HTML/CSS;Ruby;SQL
# 3   C#;JavaScript;SQL;TypeScript;HTML;CSS;Bash/Shell
# 4  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
#
#                               LanguageDesireNextYear  \
# 0                                                NaN
# 1                                C;C#;JavaScript;SQL
# 2                                    Java;Ruby;Scala
# 3   C#;JavaScript;SQL;TypeScript;HTML;CSS;Bash/Shell
# 4  Bash/Shell/PowerShell;HTML/CSS;JavaScript;Rust...
#
#                                   DatabaseWorkedWith  \
# 0                                                NaN
# 1                                       MySQL;SQLite
# 2                      MySQL;PostgreSQL;Redis;SQLite
# 3  SQL Server;Microsoft Azure (Tables, CosmosDB, ...
# 4                  Couchbase;DynamoDB;Firebase;MySQL
#
#                               DatabaseDesireNextYear  \
# 0                                                NaN
# 1                                       MySQL;SQLite
# 2                                   MySQL;PostgreSQL
# 3  SQL Server;Microsoft Azure (Tables, CosmosDB, ...
# 4                               Firebase;MySQL;Redis
#
#                                   PlatformWorkedWith  \
# 0                                                NaN
# 1                                      Linux;Windows
# 2                     AWS;Docker;Linux;MacOS;Windows
# 3                                              Azure
# 4  Android;AWS;Docker;IBM Cloud or Watson;iOS;Lin...
#
#                               PlatformDesireNextYear Hobbyist  \
# 0                                                NaN      NaN
# 1                                      Linux;Windows       No
# 2  Docker;Google Cloud Platform;Heroku;Linux;Windows      Yes
# 3                                              Azure      NaN
# 4  Android;AWS;Docker;IBM Cloud or Watson;Linux;S...      Yes
#
#                 OrgSize  YearsCodePro  \
# 0                   NaN           NaN
# 1  100 to 499 employees           1.0
# 2                   NaN           8.0
# 3                   NaN           4.0
# 4    10 to 19 employees           8.0
#
#                                         JobSeek  ConvertedComp  WorkWeekHrs
# 0                                           NaN       141000.0          NaN
# 1  I am not interested in new job opportunities        61000.0         80.0
# 2                                           NaN            NaN          NaN
# 3                                           NaN        48000.0          NaN
# 4  I am not interested in new job opportunities        90000.0         40.0

# %%
# ніколи не робив
print('% Missing Data:')
print((1 - df.count() / maxRows) * 100)
# Out:
# % Missing Data:
# RespondentID               0.000000
# Year                       0.000000
# Country                    0.000000
# Employment                 1.604187
# UndergradMajor            11.470295
# DevType                    9.689863
# LanguageWorkedWith         8.264619
# LanguageDesireNextYear    13.636486
# DatabaseWorkedWith        22.794918
# DatabaseDesireNextYear    33.248208
# PlatformWorkedWith        17.624473
# PlatformDesireNextYear    23.229235
# Hobbyist                  38.537349
# OrgSize                   50.719816
# YearsCodePro              14.761395
# JobSeek                   45.547573
# ConvertedComp             17.872654
# WorkWeekHrs               54.060373
# dtype: float64

# %%
df.drop(['NEWJobHunt','NEWJobHuntResearch','NEWLearn'],
    axis=1,
    inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df.drop(['NEWJobHunt','NEWJobHuntResearch','NEWLearn'],
#       2     axis=1,
#       3     inplace=True)
#
# File c:\Users\roman.prylypko\AppData\Local\anaconda3\envs\eda\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)   5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)   5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File c:\Users\roman.prylypko\AppData\Local\anaconda3\envs\eda\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File c:\Users\roman.prylypko\AppData\Local\anaconda3\envs\eda\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File c:\Users\roman.prylypko\AppData\Local\anaconda3\envs\eda\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['NEWJobHunt', 'NEWJobHuntResearch', 'NEWLearn'] not found in axis"

# %%
df.columns
# Out:
# Index(['RespondentID', 'Year', 'Country', 'Employment', 'UndergradMajor',
#        'DevType', 'LanguageWorkedWith', 'LanguageDesireNextYear',
#        'DatabaseWorkedWith', 'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'Hobbyist', 'OrgSize', 'YearsCodePro',
#        'JobSeek', 'ConvertedComp', 'WorkWeekHrs'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df[['RespondentID','Country']].groupby('Country').count()

missingData = df[['Employment','DevType']].isnull().groupby(df['Country']).sum().reset_index()

A=sns.catplot(
    data=missingData, kind="bar",
    x="Country", y="Employment",
    height = 6, aspect = 2)

B=sns.catplot(
    data=missingData, kind="bar",
    x="Country", y="DevType",
    height = 6, aspect = 2)

# %%
df[['RespondentID','Country']].groupby('Country').count()
# Out:
#                 RespondentID
# Country
# Canada                  8979
# China                   2072
# France                  6861
# Germany                16215
# Japan                   1049
# Mexico                  1918
# Spain                   4534
# United Kingdom         15854
# United States          53727

# %%
# You determine that the missing data for these two columns can be categorized as MCAR. This means you can safely delete the rows that have missing data in these columns! This is a prime example of where you can employ Pairwise Deletion to only delete rows that have missing data for either Employment or DevType:
df[['RespondentID','Country', 
    'Employment', 'DevType']].head()
# Out:
#    RespondentID        Country          Employment  \
# 0             1  United States  Employed full-time
# 1             1  United States  Employed full-time
# 2             1  United States  Employed full-time
# 3             2  United States  Employed full-time
# 4             2  United States  Employed full-time
#
#                                              DevType
# 0           Engineering manager;Full-stack developer
# 1                              Developer, full-stack
# 2                                                NaN
# 3                               Full-stack developer
# 4  Data or business analyst;Database administrato...

# %%
df.dropna(subset = ['Employment','DevType'],
    inplace = True,
    how = 'any')

# %%
maxRows = df['RespondentID'].count()

# %%
# ніколи не робив
print('% Missing Data:')
print((1 - df.count() / maxRows) * 100)
# Out:
# % Missing Data:
# RespondentID               0.000000
# Year                       0.000000
# Country                    0.000000
# Employment                 0.000000
# UndergradMajor             9.392348
# DevType                    0.000000
# LanguageWorkedWith         6.462616
# LanguageDesireNextYear    11.876969
# DatabaseWorkedWith        19.738935
# DatabaseDesireNextYear    30.636659
# PlatformWorkedWith        15.726932
# PlatformDesireNextYear    21.427357
# Hobbyist                  40.055014
# OrgSize                   46.137534
# YearsCodePro              13.426357
# JobSeek                   43.034759
# ConvertedComp             16.663166
# WorkWeekHrs               49.695424
# dtype: float64

# %%
empfig = sns.catplot(x="Country", col="Employment",
                data=df, kind="count",
                height=6, aspect=1.5, palette="Set2")

# Focus on a few of the key developer types outlined in the Stack Overflow survey
devdf = df[['Country','DevType']]
devdf.loc[devdf['DevType'].str.contains('back-end'), 'BackEnd'] = True
devdf.loc[devdf['DevType'].str.contains('front-end'), 'FrontEnd'] = True
devdf.loc[devdf['DevType'].str.contains('full-stack'), 'FullStack'] = True
devdf.loc[devdf['DevType'].str.contains('mobile'), 'Mobile'] = True
devdf.loc[devdf['DevType'].str.contains('administrator'), 'Admin'] = True

devdf = devdf.melt(id_vars=['Country'], 
    value_vars=['BackEnd','FrontEnd','FullStack','Mobile','Admin'], 
    var_name='DevCat',
    value_name='DevFlag')

devdf.dropna(how='any', inplace=True)

devFig = sns.catplot(x="Country", col="DevCat",
                data=devdf, kind="count",
                height=6, aspect=1.5, palette="Set2")
# Out:
# C:\Users\roman.prylypko\AppData\Local\Temp\ipykernel_27092\809589838.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   empfig = sns.catplot(x="Country", col="Employment",
# C:\Users\roman.prylypko\AppData\Local\Temp\ipykernel_27092\809589838.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   devdf.loc[devdf['DevType'].str.contains('back-end'), 'BackEnd'] = True
# C:\Users\roman.prylypko\AppData\Local\Temp\ipykernel_27092\809589838.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   devdf.loc[devdf['DevType'].str.contains('front-end'), 'FrontEnd'] = True
# C:\Users\roman.prylypko\AppData\Local\Temp\ipykernel_27092\809589838.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   devdf.loc[devdf['DevType'].str.contains('full-stack'), 'FullStack'] = True
# C:\Users\roman.prylypko\AppData\Local\Temp\ipykernel_27092\809589838.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   devdf.loc[devdf['DevType'].str.contains('mobile'), 'Mobile'] = True
# C:\Users\roman.prylypko\AppData\Local\Temp\ipykernel_27092\809589838.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   devdf.loc[devdf['DevType'].str.contains('administrator'), 'Admin'] = True
# C:\Users\roman.prylypko\AppData\Local\Temp\ipykernel_27092\809589838.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   devFig = sns.catplot(x="Country", col="DevCat",

# %%
missingUndergrad = df['UndergradMajor'].isnull().groupby(df['Year']).sum().reset_index()

sns.catplot(x="Year", y="UndergradMajor"
            , data=missingUndergrad, kind="bar",
                height=4, aspect=1)

# %%
df = df.sort_values(['RespondentID','Year'])
df['UndergradMajor'].bfill(axis=0, inplace=True)
df
# Out:
# C:\Users\roman.prylypko\AppData\Local\Temp\ipykernel_27092\1349460168.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['UndergradMajor'].bfill(axis=0, inplace=True)
#         RespondentID  Year        Country  \
# 0                  1  2018  United States
# 1                  1  2019  United States
# 3                  2  2018  United States
# 4                  2  2019  United States
# 5                  2  2020  United States
# ...              ...   ...            ...
# 111187         42836  2018          Japan
# 111188         42837  2018          Japan
# 111190         42839  2018          Japan
# 111191         42840  2018          Japan
# 111198         42847  2018          Japan
#
#                                                Employment  \
# 0                                      Employed full-time
# 1                                      Employed full-time
# 3                                      Employed full-time
# 4                                      Employed full-time
# 5                                      Employed full-time
# ...                                                   ...
# 111187  Independent contractor, freelancer, or self-em...
# 111188                 Not employed, but looking for work
# 111190  Independent contractor, freelancer, or self-em...
# 111191             Not employed, and not looking for work
# 111198  Independent contractor, freelancer, or self-em...
#
#                                            UndergradMajor  \
# 0       Computer science, computer engineering, or sof...
# 1       Computer science, computer engineering, or sof...
# 3       Computer science, computer engineering, or sof...
# 4       Computer science, computer engineering, or sof...
# 5       Computer science, computer engineering, or sof...
# ...                                                   ...
# 111187  Computer science, computer engineering, or sof...
# 111188  Computer science, computer engineering, or sof...
# 111190  A humanities discipline (ex. literature, histo...
# 111191                                                NaN
# 111198                                                NaN
#
#                                                   DevType  \
# 0                Engineering manager;Full-stack developer
# 1                                   Developer, full-stack
# 3                                    Full-stack developer
# 4       Data or business analyst;Database administrato...
# 5       Developer, back-end;Developer, desktop or ente...
# ...                                                   ...
# 111187  Back-end developer;Desktop or enterprise appli...
# 111188  Back-end developer;Desktop or enterprise appli...
# 111190  Back-end developer;Front-end developer;Full-st...
# 111191                        Front-end developer;Student
# 111198  Back-end developer;Front-end developer;Mobile ...
#
#                                        LanguageWorkedWith  \
# 0                                                     NaN
# 1                                     C;C++;C#;Python;SQL
# 3        C#;JavaScript;SQL;TypeScript;HTML;CSS;Bash/Shell
# 4       Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 5                                              Python;SQL
# ...                                                   ...
# 111187             Java;JavaScript;SQL;VBA;Cobol;HTML;CSS
# 111188                                               Java
# 111190                                                NaN
# 111191                                                NaN
# 111198                                                NaN
#
#                                    LanguageDesireNextYear  \
# 0                                                     NaN
# 1                                     C;C#;JavaScript;SQL
# 3        C#;JavaScript;SQL;TypeScript;HTML;CSS;Bash/Shell
# 4       Bash/Shell/PowerShell;HTML/CSS;JavaScript;Rust...
# 5                                              JavaScript
# ...                                                   ...
# 111187                                          C#;Python
# 111188                           Java;JavaScript;HTML;CSS
# 111190                                                NaN
# 111191                                                NaN
# 111198                                                NaN
#
#                                        DatabaseWorkedWith  \
# 0                                                     NaN
# 1                                            MySQL;SQLite
# 3       SQL Server;Microsoft Azure (Tables, CosmosDB, ...
# 4                       Couchbase;DynamoDB;Firebase;MySQL
# 5                                     MariaDB;MySQL;Redis
# ...                                                   ...
# 111187                                       MySQL;Oracle
# 111188                              SQL Server;PostgreSQL
# 111190                                                NaN
# 111191                                                NaN
# 111198                                                NaN
#
#                                    DatabaseDesireNextYear  \
# 0                                                     NaN
# 1                                            MySQL;SQLite
# 3       SQL Server;Microsoft Azure (Tables, CosmosDB, ...
# 4                                    Firebase;MySQL;Redis
# 5                                                 MongoDB
# ...                                                   ...
# 111187  Amazon DynamoDB;Amazon Redshift;Amazon RDS/Aur...
# 111188                                         PostgreSQL
# 111190                                                NaN
# 111191                                                NaN
# 111198                                                NaN
#
#                                        PlatformWorkedWith  \
# 0                                                     NaN
# 1                                           Linux;Windows
# 3                                                   Azure
# 4       Android;AWS;Docker;IBM Cloud or Watson;iOS;Lin...
# 5                                                  Docker
# ...                                                   ...
# 111187          Linux;Mainframe;Windows Desktop or Server
# 111188                                              Linux
# 111190                                                NaN
# 111191                                                NaN
# 111198                                                NaN
#
#                                    PlatformDesireNextYear Hobbyist  \
# 0                                                     NaN      NaN
# 1                                           Linux;Windows       No
# 3                                                   Azure      NaN
# 4       Android;AWS;Docker;IBM Cloud or Watson;Linux;S...      Yes
# 5                         iOS;Slack Apps and Integrations      Yes
# ...                                                   ...      ...
# 111187       Android;AWS;Google Cloud Platform/App Engine      NaN
# 111188                                              Linux      NaN
# 111190                                                NaN      NaN
# 111191                                                NaN      NaN
# 111198                                                NaN      NaN
#
#                      OrgSize  YearsCodePro  \
# 0                        NaN           NaN
# 1       100 to 499 employees           1.0
# 3                        NaN           4.0
# 4         10 to 19 employees           8.0
# 5         20 to 99 employees          13.0
# ...                      ...           ...
# 111187                   NaN           NaN
# 111188                   NaN           NaN
# 111190                   NaN           NaN
# 111191                   NaN           NaN
# 111198                   NaN           1.0
#
#                                                   JobSeek  ConvertedComp  \
# 0                                                     NaN       141000.0
# 1            I am not interested in new job opportunities        61000.0
# 3                                                     NaN        48000.0
# 4            I am not interested in new job opportunities        90000.0
# 5       I’m not actively looking, but I am open to new...       116000.0
# ...                                                   ...            ...
# 111187                                                NaN        93000.0
# 111188                                                NaN       116000.0
# 111190                                                NaN         8000.0
# 111191                                                NaN        71000.0
# 111198                                                NaN       144000.0
#
#         WorkWeekHrs
# 0               NaN
# 1              80.0
# 3               NaN
# 4              40.0
# 5              39.0
# ...             ...
# 111187          NaN
# 111188          NaN
# 111190          NaN
# 111191          NaN
# 111198          NaN
#
# [99975 rows x 18 columns]

# %%
majors = ['social science','natural science','computer science','development','another engineering','never declared']

edudf = df[['Year','UndergradMajor']]
edudf.dropna(how='any', inplace=True)
edudf.loc[edudf['UndergradMajor'].str.contains('(?i)social science'), 'SocialScience'] = True
edudf.loc[edudf['UndergradMajor'].str.contains('(?i)natural science'), 'NaturalScience'] = True
edudf.loc[edudf['UndergradMajor'].str.contains('(?i)computer science'), 'ComSci'] = True
edudf.loc[edudf['UndergradMajor'].str.contains('(?i)development'), 'ComSci'] = True
edudf.loc[edudf['UndergradMajor'].str.contains('(?i)another engineering'), 'OtherEng'] = True
edudf.loc[edudf['UndergradMajor'].str.contains('(?i)never declared'), 'NoMajor'] = True

edudf = edudf.melt(id_vars=['Year'], 
    value_vars=['SocialScience','NaturalScience','ComSci','OtherEng','NoMajor'], 
    var_name='EduCat',
    value_name='EduFlag')

edudf.dropna(how='any', inplace=True)
edudf = edudf.groupby(['Year','EduCat']).count().reset_index()

eduFig = sns.catplot(x="Year", y='EduFlag', col="EduCat",
                data=edudf, kind="bar",
                height=6, aspect=1.5);
# Out:
# C:\Users\roman.prylypko\AppData\Local\Temp\ipykernel_27092\2307531551.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edudf.dropna(how='any', inplace=True)
# C:\Users\roman.prylypko\AppData\Local\Temp\ipykernel_27092\2307531551.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edudf.loc[edudf['UndergradMajor'].str.contains('(?i)social science'), 'SocialScience'] = True
# C:\Users\roman.prylypko\AppData\Local\Temp\ipykernel_27092\2307531551.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edudf.loc[edudf['UndergradMajor'].str.contains('(?i)natural science'), 'NaturalScience'] = True
# C:\Users\roman.prylypko\AppData\Local\Temp\ipykernel_27092\2307531551.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edudf.loc[edudf['UndergradMajor'].str.contains('(?i)computer science'), 'ComSci'] = True
# C:\Users\roman.prylypko\AppData\Local\Temp\ipykernel_27092\2307531551.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edudf.loc[edudf['UndergradMajor'].str.contains('(?i)another engineering'), 'OtherEng'] = True
# C:\Users\roman.prylypko\AppData\Local\Temp\ipykernel_27092\2307531551.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edudf.loc[edudf['UndergradMajor'].str.contains('(?i)never declared'), 'NoMajor'] = True

# %%
compFields = df[['Year','YearsCodePro','ConvertedComp']]

D = sns.boxplot(x="Year", y="YearsCodePro",
            data=compFields)

# %%
E = sns.boxplot(x="Year", y="ConvertedComp",
            data=compFields)

# %%
# Можна застосувати якщо є гіпотеза про кореляцію між двома змінними, інакше це буде просто рандомна заміна
import numpy as np
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.model_selection import train_test_split

imputedf = df[['YearsCodePro','ConvertedComp']]

traindf, testdf = train_test_split(imputedf, train_size=0.1)

# Create the IterativeImputer model to predict missing values
imp = IterativeImputer(max_iter=20, random_state=0)

# Fit the model to the the test dataset
imp.fit(imputedf)

# Transform the model on the entire dataset
compdf = pd.DataFrame(np.round(imp.transform(imputedf),0), columns=['YearsCodePro','ConvertedComp'])

# %%
compPlotdf = compdf.loc[compdf['ConvertedComp'] <= 150000]
compPlotdf['CodeYearBins'] = pd.qcut(compPlotdf['YearsCodePro'], q=5)

sns.boxplot(x="CodeYearBins", y="ConvertedComp",
            data=compPlotdf)
# Out:
# C:\Users\roman.prylypko\AppData\Local\Temp\ipykernel_27092\162640794.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   compPlotdf['CodeYearBins'] = pd.qcut(compPlotdf['YearsCodePro'], q=5)
# <Axes: xlabel='CodeYearBins', ylabel='ConvertedComp'>
